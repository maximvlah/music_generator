# %% [markdown]
# # Convert midi to csv

# %%
import pandas as pandas
import py_midicsv as pm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-29877a67604b> in <module>
#       1 import pandas as pandas
# ----> 2 import py_midicsv as pm
#
# ModuleNotFoundError: No module named 'py_midicsv'

# %%
# Load the MIDI file and parse it into CSV format
csv_string = pm.midi_to_csv("example.mid")

with open("example_converted.csv", "w") as f:
    f.writelines(csv_string)

# Parse the CSV output of the previous command back into a MIDI file
midi_object = pm.csv_to_midi(csv_string)

# Save the parsed MIDI file to disk
with open("example_converted.mid", "wb") as output_file:
    midi_writer = pm.FileWriter(output_file)
    midi_writer.write(midi_object)

# %%
# !conda list
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.
